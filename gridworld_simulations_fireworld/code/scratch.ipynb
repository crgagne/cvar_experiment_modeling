# %%
import numpy as np
import matplotlib.pyplot as plt
import example_tasks
import plot_multiple
import importlib

# %%
importlib.reload(example_tasks)
task= example_tasks.task_straight
fig, ax = plt.subplots()
plot_multiple.plot_gridworld(ax, task)
plt.show()
